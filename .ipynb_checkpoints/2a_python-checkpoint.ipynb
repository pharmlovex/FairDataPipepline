# %%
# Clone the simple model repo
# !git clone https://github.com/FAIRDataPipeline/pySimpleModel.git
# Out:
# Cloning into 'pySimpleModel'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 199 (delta 20), reused 34 (delta 10), pack-reused 136
# Receiving objects: 100% (199/199), 43.78 KiB | 2.30 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# Install the simple model
import sys
# !{sys.executable} -m pip install ./pySimpleModel
# Out:
# Processing ./pySimpleModel
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting data-pipeline-api (from pySimpleModel==0.7.7)
#   Downloading data_pipeline_api-0.7.13-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/conda/lib/python3.11/site-packages (from data-pipeline-api->pySimpleModel==0.7.7) (6.0.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.5.1 in /opt/conda/lib/python3.11/site-packages (from data-pipeline-api->pySimpleModel==0.7.7) (3.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /opt/conda/lib/python3.11/site-packages (from data-pipeline-api->pySimpleModel==0.7.7) (2.31.0)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in /opt/conda/lib/python3.11/site-packages (from data-pipeline-api->pySimpleModel==0.7.7) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->data-pipeline-api->pySimpleModel==0.7.7) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->data-pipeline-api->pySimpleModel==0.7.7) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->data-pipeline-api->pySimpleModel==0.7.7) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->data-pipeline-api->pySimpleModel==0.7.7) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.5.1->data-pipeline-api->pySimpleModel==0.7.7) (1.16.0)
# Downloading data_pipeline_api-0.7.13-py3-none-any.whl (28 kB)
# Building wheels for collected packages: pySimpleModel
#   Building wheel for pySimpleModel (pyproject.toml) ... done
#   Created wheel for pySimpleModel: filename=pysimplemodel-0.7.7-py3-none-any.whl size=18754 sha256=ebf8a573b8a882c6730bd8f683d97d61bde700b0dc38c835991a29022a3db87c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2zji5ezw/wheels/e1/62/ff/9f959763c52498f9d357f56a7667948397e904a8c98616e839
# Successfully built pySimpleModel
# Installing collected packages: data-pipeline-api, pySimpleModel
# Successfully installed data-pipeline-api-0.7.13 pySimpleModel-0.7.7

# %%
# Change into the Python Simple Model Directory
import os
os.chdir('pySimpleModel')

# %%
# Initialise a 'fair' repository for local use without user prompts
# !fair init --ci --local --debug
# Out:
# DEBUG:FAIRDataPipeline.Session:Starting new session.
# DEBUG:FAIRDataPipeline.Session:Session location: /home/jovyan/pySimpleModel
# DEBUG:FAIRDataPipeline.Staging:Creating stager for FAIR repository '/home/jovyan/pySimpleModel'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling missing metadata
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_read_version=${{LATEST}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.Session:Initialising session with:
# 	location       = /home/jovyan/pySimpleModel
# 	session_config = None
# 	testing        = True
# 	run_mode       = SwitchMode.NO_SERVER
# 	staging_file   = /home/jovyan/pySimpleModel/.fair/staging
# 	session_id     = None
# 	local          = True
#
# DEBUG:FAIRDataPipeline.Session:Loading CLI configurations.
# DEBUG:FAIRDataPipeline.Session:Running server setup for run mode SwitchMode.NO_SERVER
# DEBUG:FAIRDataPipeline.Staging:Creating new staging cache file
# DEBUG:FAIRDataPipeline.Server:Updating registry from latest setup
# DEBUG:FAIRDataPipeline.Server:Checking if server is running on 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Server:Populating file types
# DEBUG:FAIRDataPipeline.Storage:Adding file types to storage
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Comma-Separated Values File' with extension 'csv'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Comma-Separated Values File", "extension": "csv"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'TOML Configuration File' with extension 'toml'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "TOML Configuration File", "extension": "toml"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'JavaScript Object Notation File' with extension 'json'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "JavaScript Object Notation File", "extension": "json"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'YAML Document' with extension 'yaml'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "YAML Document", "extension": "yaml"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Windows Initialization File' with extension 'ini'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Windows Initialization File", "extension": "ini"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Data File' with extension 'dat'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Data File", "extension": "dat"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Python NumPy Array File' with extension 'npy'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Python NumPy Array File", "extension": "npy"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Microsoft Excel Spreadsheet (Legacy)' with extension 'xls'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Microsoft Excel Spreadsheet (Legacy)", "extension": "xls"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Microsoft Excel Spreadsheet' with extension 'xlsx'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Microsoft Excel Spreadsheet", "extension": "xlsx"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Microsoft Word Document (Legacy)' with extension 'doc'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Microsoft Word Document (Legacy)", "extension": "doc"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Microsoft Word Document' with extension 'docx'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Microsoft Word Document", "extension": "docx"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Plain Text File' with extension 'txt'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Plain Text File", "extension": "txt"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'R Script File' with extension 'R'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "R Script File", "extension": "r"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Windows Executable File' with extension 'exe'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Windows Executable File", "extension": "exe"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Julia Source Code File' with extension 'jl'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Julia Source Code File", "extension": "jl"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Java Source Code File' with extension 'java'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Java Source Code File", "extension": "java"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Bash Shell Script' with extension 'sh'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Bash Shell Script", "extension": "sh"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Windows PowerShell Cmdlet File' with extension 'ps1'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Windows PowerShell Cmdlet File", "extension": "ps1"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Hierarchical Data Format 5 File' with extension 'h5'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Hierarchical Data Format 5 File", "extension": "h5"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Hierarchical Data Format 5 File' with extension 'hdf5'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Hierarchical Data Format 5 File", "extension": "hdf5"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Program Database' with extension 'pdb'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Program Database", "extension": "pdb"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Zipped File' with extension 'zip'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Zipped File", "extension": "zip"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Consolidated Unix File Archive' with extension 'tar'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Consolidated Unix File Archive", "extension": "tar"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Compressed Tarball File' with extension 'tar.gz'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Compressed Tarball File", "extension": "tar.gz"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Gnu Zipped Archive' with extension 'gz'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Gnu Zipped Archive", "extension": "gz"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'XML File' with extension 'xml'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "XML File", "extension": "xml"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'ASCII Text File' with extension 'ascii'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "ASCII Text File", "extension": "ascii"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Structured Query Language Data File' with extension 'sql'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Structured Query Language Data File", "extension": "sql"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'SAS Program File' with extension 'sas'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "SAS Program File", "extension": "sas"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'R Workspace File' with extension 'rdata'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "R Workspace File", "extension": "rdata"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Typinator Set File' with extension 'tab'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Typinator Set File", "extension": "tab"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Configuration File' with extension 'cfg'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Configuration File", "extension": "cfg"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Python Pickle File' with extension 'pkl'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Python Pickle File", "extension": "pkl"}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Python Script' with extension 'py'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Python Script", "extension": "py"}
# DEBUG:FAIRDataPipeline.Server:Adding 'author' and 'UserAuthor' entries if not present
# DEBUG:FAIRDataPipeline.Storage:Storing user 'Interface Test'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'author' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Key in post data 'uuid' has no value so will be ignored
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/author/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Interface Test", "identifier": "https://github.com/FAIRDataPipeline"}
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'users' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'username': 'admin'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/users/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'username': 'admin'}
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'user_author' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/user_author/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"user": "http://127.0.0.1:8000/api/users/1/", "author": "http://127.0.0.1:8000/api/author/1/"}
# Initialised empty fair repository in /home/jovyan/pySimpleModel/.fair

# %%
# Register the data product from the Config Yaml
# !fair pull --debug --local simpleModel/ext/SEIRSconfig.yaml
# Out:
# Running pull please wait
# DEBUG:FAIRDataPipeline.Session:Starting new session.
# DEBUG:FAIRDataPipeline.Session:Session location: /home/jovyan/pySimpleModel
# DEBUG:FAIRDataPipeline.Staging:Creating stager for FAIR repository '/home/jovyan/pySimpleModel'
# DEBUG:FAIRDataPipeline.ConfigYAML:Loading file 'simpleModel/ext/SEIRSconfig.yaml'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling missing metadata
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_read_version=${{LATEST}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.Session:Initialising session with:
# 	location       = /home/jovyan/pySimpleModel
# 	session_config = simpleModel/ext/SEIRSconfig.yaml
# 	testing        = False
# 	run_mode       = SwitchMode.CLI
# 	staging_file   = /home/jovyan/pySimpleModel/.fair/staging
# 	session_id     = 860cc20c-04f2-40c8-872f-53286a839cd8
# 	local          = True
#
# DEBUG:FAIRDataPipeline.Session:Loading CLI configurations.
# DEBUG:FAIRDataPipeline.Session:Running server setup for run mode SwitchMode.CLI
# DEBUG:FAIRDataPipeline.Session:Checking for existing sessions
# DEBUG:FAIRDataPipeline.Session:Creating new session #860cc20c-04f2-40c8-872f-53286a839cd8
# DEBUG:FAIRDataPipeline.Session:Running pre-job setup
# DEBUG:FAIRDataPipeline.ConfigYAML:Updating configuration from /home/jovyan/pySimpleModel
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:local_repo=/home/jovyan/pySimpleModel'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_output_namespace=testing'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:remote_data_registry_url=http://127.0.0.1:8001/api/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:write_data_store=/home/jovyan/pySimpleModel/.fair/data_store/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:remote_data_registry_url=http://127.0.0.1:8001/api/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Preparing configuration
# DEBUG:FAIRDataPipeline.ConfigYAML:Updating namespace list
# DEBUG:FAIRDataPipeline.ConfigYAML:Handling 'register:namespace'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Storage:Storing namespace 'PSU' on registry
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'namespace' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "PSU", "full_name": "Pennsylvania State University", "website": "https://ror.org/04p491231"}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false'}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Handling 'register:author'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false'}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false', 'use': {'namespace': 'PSU'}}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling all namespaces
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false', 'use': {'namespace': 'PSU'}}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling all namespaces
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing'}}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing'}}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Will write session log to '/home/jovyan/pySimpleModel/.fair/logs/job_2024-06-12_13_47_07_750697.log'
# DEBUG:FAIRDataPipeline.ConfigYAML:Searching for CLI variables
# DEBUG:FAIRDataPipeline.ConfigYAML:Found datetime substitutions:
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling 'register' block
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'description': 'Static parameters of the model', 'external_object': 'SEIRS_model/parameters', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters'}, 'version': '1.0.0', 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling 'write' block
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing', 'version': '${{PATCH}}', 'data_product': 'SEIRS_model/results/model_output/python'}, 'public': True}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing', 'version': '${{PATCH}}', 'data_product': 'SEIRS_model/results/figure/python'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling 'read' block
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling version information
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'data_product' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'SEIRS_model/parameters', 'namespace': '1', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/data_product/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'SEIRS_model/parameters', 'namespace': '1', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'description': 'Static parameters of the model', 'external_object': 'SEIRS_model/parameters', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters', 'version': '1.0.0'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling version information
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing', 'version': '0.0.1', 'data_product': 'SEIRS_model/results/model_output/python'}, 'public': True}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing', 'version': '0.0.1', 'data_product': 'SEIRS_model/results/figure/python'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Fetching registrations
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'data_product' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'SEIRS_model/parameters'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/data_product/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'SEIRS_model/parameters'}
# DEBUG:FAIRDataPipeline.Sync:Downloaded file from 'https://raw.githubusercontent.com/FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv' to temporary file
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'external_object' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/external_object/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.Register:No existing results found for {'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.Register:Saving data file to '/home/jovyan/pySimpleModel/.fair/data_store/PSU/SEIRS_model/parameters/1.0.0.csv'
# INFO:FAIRDataPipeline.Register:Registering: SEIRS_model/parameters
# DEBUG:FAIRDataPipeline.Storage:Storing data file '/home/jovyan/pySimpleModel/.fair/data_store/PSU/SEIRS_model/parameters/1.0.0.csv' on registry
# DEBUG:FAIRDataPipeline.Storage:Constructing a storage root for '/home/jovyan/pySimpleModel/.fair/data_store/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'storage_root' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'root': 'file:///home/jovyan/pySimpleModel/.fair/data_store/'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/storage_root/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'root': 'file:///home/jovyan/pySimpleModel/.fair/data_store/'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/storage_root/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"root": "file:///home/jovyan/pySimpleModel/.fair/data_store/", "local": true}
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'storage_location' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/storage_location/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"path": "PSU/SEIRS_model/parameters/1.0.0.csv", "storage_root": "http://127.0.0.1:8000/api/storage_root/1/", "public": "true", "hash": "6294a5951677e6b8438cabf55234b7974adeaee3"}
# DEBUG:FAIRDataPipeline.Storage:Storing user 'Interface Test'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'author' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Key in post data 'uuid' has no value so will be ignored
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/author/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Interface Test", "identifier": "https://github.com/FAIRDataPipeline"}
# DEBUG:FAIRDataPipeline.Requests:[HTTP 409]: Cannot post object of type 'author' using method 'post' as it already exists.Arguments:
# url = http://127.0.0.1:8000/api/author/,  data = {"name": "Interface Test", "identifier": "https://github.com/FAIRDataPipeline"}
# DEBUG:FAIRDataPipeline.Requests:Object already exists, retrieving entry
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'author' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'Interface Test'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/author/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'Interface Test'}
# DEBUG:FAIRDataPipeline.Storage:Adding file type 'Comma-Separated Values File' with extension 'csv'
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'file_type' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "Comma-Separated Values File", "extension": "csv"}
# DEBUG:FAIRDataPipeline.Requests:[HTTP 409]: Cannot post object of type 'file_type' using method 'post' as it already exists.Arguments:
# url = http://127.0.0.1:8000/api/file_type/,  data = {"name": "Comma-Separated Values File", "extension": "csv"}
# DEBUG:FAIRDataPipeline.Requests:Object already exists, retrieving entry
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'file_type' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'extension': 'csv'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/file_type/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'extension': 'csv'}
# DEBUG:FAIRDataPipeline.Storage:Storing namespace 'PSU' on registry
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'namespace' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Key in post data 'full_name' has no value so will be ignored
# DEBUG:FAIRDataPipeline.Requests:Key in post data 'website' has no value so will be ignored
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "PSU"}
# DEBUG:FAIRDataPipeline.Requests:[HTTP 409]: Cannot post object of type 'namespace' using method 'post' as it already exists.Arguments:
# url = http://127.0.0.1:8000/api/namespace/,  data = {"name": "PSU"}
# DEBUG:FAIRDataPipeline.Requests:Object already exists, retrieving entry
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/object/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"description": "Static parameters of the model", "file_type": "http://127.0.0.1:8000/api/file_type/1/", "storage_location": "http://127.0.0.1:8000/api/storage_location/1/", "authors": ["http://127.0.0.1:8000/api/author/1/"]}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/data_product/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"namespace": "http://127.0.0.1:8000/api/namespace/1/", "object": "http://127.0.0.1:8000/api/object/1/", "version": "1.0.0", "name": "SEIRS_model/parameters"}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/external_object/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"data_product": "http://127.0.0.1:8000/api/data_product/1/", "title": "Static parameters of the model", "primary_not_supplement": "false", "release_date": "2021-09-20T12:00", "identifier": "https://doi.org/10.1038/s41592-020-0856-2"}
# DEBUG:FAIRDataPipeline.ConfigYAML:Fetched objects:
#  [{'url': 'http://127.0.0.1:8000/api/external_object/1/', 'last_updated': '2024-06-12T13:47:09.150356Z', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'alternate_identifier': None, 'alternate_identifier_type': None, 'primary_not_supplement': False, 'release_date': '2021-09-20T12:00:00Z', 'title': 'Static parameters of the model', 'description': None, 'version': '1.0.0', 'updated_by': 'http://127.0.0.1:8000/api/users/1/', 'data_product': 'http://127.0.0.1:8000/api/data_product/1/', 'original_store': None}]
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: None
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'author' from registry at 'http://127.0.0.1:8000/api/' with parameters: None
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/author/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value read=[]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value read=[{'description': 'Static parameters of the model', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters', 'version': '1.0.0'}, 'data_product': 'SEIRS_model/parameters', 'registered': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value read=[{'description': 'Static parameters of the model', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters', 'version': '1.0.0'}, 'data_product': 'SEIRS_model/parameters', 'registered': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Cleaning configuration
# DEBUG:FAIRDataPipeline.ConfigYAML:Checking for unparsed variables
# DEBUG:FAIRDataPipeline.ConfigYAML:Retrieving latest commit SHA with allow_dirty=True
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:latest_commit=c592f3bb913b69258f51b22b8d77b5fe44d4e12e'
# DEBUG:FAIRDataPipeline.ConfigYAML:Running configuration validation
# DEBUG:FAIRDataPipeline.ConfigYAML:Retrieving list of 'read' items
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.script_path=None'
# DEBUG:FAIRDataPipeline.ConfigYAML:Configuration written to '/home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_07_750697/config.yaml'
# DEBUG:FAIRDataPipeline.Session:Preparing to retrieve 0 items
# DEBUG:FAIRDataPipeline.Session:Pulling data products locally
# There are no items in the [read] block to pull from registry: 'origin'.
# DEBUG:FAIRDataPipeline.Session:Performing post-job breakdown
# DEBUG:FAIRDataPipeline.Session:Updating staging post-run
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/data_product/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/1/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}

# %%
# Run the Python Simple Model as define in the Config Yaml
# !fair run --debug --local simpleModel/ext/SEIRSconfig.yaml
# Out:
# Running run please wait
# DEBUG:FAIRDataPipeline.Session:Starting new session.
# DEBUG:FAIRDataPipeline.Session:Session location: /home/jovyan/pySimpleModel
# DEBUG:FAIRDataPipeline.Staging:Creating stager for FAIR repository '/home/jovyan/pySimpleModel'
# DEBUG:FAIRDataPipeline.ConfigYAML:Loading file 'simpleModel/ext/SEIRSconfig.yaml'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling missing metadata
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_read_version=${{LATEST}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.Session:Initialising session with:
# 	location       = /home/jovyan/pySimpleModel
# 	session_config = simpleModel/ext/SEIRSconfig.yaml
# 	testing        = False
# 	run_mode       = SwitchMode.CLI
# 	staging_file   = /home/jovyan/pySimpleModel/.fair/staging
# 	session_id     = 0f9b78f0-2628-4766-899e-8272a66f52dd
# 	local          = True
#
# DEBUG:FAIRDataPipeline.Session:Loading CLI configurations.
# DEBUG:FAIRDataPipeline.Session:Running server setup for run mode SwitchMode.CLI
# DEBUG:FAIRDataPipeline.Session:Checking for existing sessions
# DEBUG:FAIRDataPipeline.Session:Creating new session #0f9b78f0-2628-4766-899e-8272a66f52dd
# DEBUG:FAIRDataPipeline.Session:Running pre-job setup
# DEBUG:FAIRDataPipeline.ConfigYAML:Updating configuration from /home/jovyan/pySimpleModel
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:local_repo=/home/jovyan/pySimpleModel'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:default_output_namespace=testing'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:remote_data_registry_url=http://127.0.0.1:8001/api/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:write_data_store=/home/jovyan/pySimpleModel/.fair/data_store/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Preparing configuration
# DEBUG:FAIRDataPipeline.ConfigYAML:Updating namespace list
# DEBUG:FAIRDataPipeline.ConfigYAML:Handling 'register:namespace'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Storage:Storing namespace 'PSU' on registry
# DEBUG:FAIRDataPipeline.Requests:Attempting to post an instance of 'namespace' to 'http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'post': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Post data: {"name": "PSU", "full_name": "Pennsylvania State University", "website": "https://ror.org/04p491231"}
# DEBUG:FAIRDataPipeline.Requests:[HTTP 409]: Cannot post object of type 'namespace' using method 'post' as it already exists.Arguments:
# url = http://127.0.0.1:8000/api/namespace/,  data = {"name": "PSU", "full_name": "Pennsylvania State University", "website": "https://ror.org/04p491231"}
# DEBUG:FAIRDataPipeline.Requests:Object already exists, retrieving entry
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false'}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Handling 'register:author'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false'}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false', 'use': {'namespace': 'PSU'}}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling all namespaces
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'external_object': 'SEIRS_model/parameters', 'namespace_name': 'PSU', 'root': 'https://raw.githubusercontent.com/', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'title': 'Static parameters of the model', 'description': 'Static parameters of the model', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'file_type': 'csv', 'release_date': '2021-09-20T12:00', 'version': '1.0.0', 'primary': 'false', 'use': {'namespace': 'PSU'}}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling all namespaces
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing'}}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing'}}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Will write session log to '/home/jovyan/pySimpleModel/.fair/logs/job_2024-06-12_13_47_09_810011.log'
# DEBUG:FAIRDataPipeline.ConfigYAML:Searching for CLI variables
# DEBUG:FAIRDataPipeline.ConfigYAML:Found datetime substitutions:
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling 'register' block
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'description': 'Static parameters of the model', 'external_object': 'SEIRS_model/parameters', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters'}, 'version': '1.0.0', 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling 'write' block
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.public=True'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing', 'version': '${{PATCH}}', 'data_product': 'SEIRS_model/results/model_output/python'}, 'public': True}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing', 'version': '${{PATCH}}', 'data_product': 'SEIRS_model/results/figure/python'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling 'read' block
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.ConfigYAML:Expanding wildcards using registry 'http://127.0.0.1:8000/api/
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'description': 'Static parameters of the model', 'external_object': 'SEIRS_model/parameters', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters'}, 'version': '1.0.0', 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing', 'version': '${{PATCH}}', 'data_product': 'SEIRS_model/results/model_output/python'}, 'public': True}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing', 'version': '${{PATCH}}', 'data_product': 'SEIRS_model/results/figure/python'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling version information
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'PSU'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'data_product' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'SEIRS_model/parameters', 'namespace': '1', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/data_product/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'SEIRS_model/parameters', 'namespace': '1', 'version': '1.0.0'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value register=[{'description': 'Static parameters of the model', 'external_object': 'SEIRS_model/parameters', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters', 'version': '1.0.0'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Filling version information
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.default_write_version=${{PATCH}}'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {'name': 'testing'}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value write=[{'data_product': 'SEIRS_model/results/model_output/python', 'description': 'SEIRS model results', 'file_type': 'csv', 'use': {'namespace': 'testing', 'version': '0.0.1', 'data_product': 'SEIRS_model/results/model_output/python'}, 'public': True}, {'data_product': 'SEIRS_model/results/figure/python', 'description': 'SEIRS output plot', 'file_type': 'png', 'use': {'namespace': 'testing', 'version': '0.0.1', 'data_product': 'SEIRS_model/results/figure/python'}, 'public': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'namespace' from registry at 'http://127.0.0.1:8000/api/' with parameters: None
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.local_data_registry_url=http://127.0.0.1:8000/api/'
# DEBUG:FAIRDataPipeline.Requests:Retrieving object of type 'author' from registry at 'http://127.0.0.1:8000/api/' with parameters: None
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/author/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value read=[]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value read=[{'description': 'Static parameters of the model', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters', 'version': '1.0.0'}, 'data_product': 'SEIRS_model/parameters', 'registered': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value read=[{'description': 'Static parameters of the model', 'file_type': 'csv', 'identifier': 'https://doi.org/10.1038/s41592-020-0856-2', 'namespace_name': 'PSU', 'path': 'FAIRDataPipeline/pySimpleModel/main/simpleModel/ext/static_params_SEIRS.csv', 'primary': 'false', 'release_date': '2021-09-20T12:00', 'root': 'https://raw.githubusercontent.com/', 'title': 'Static parameters of the model', 'use': {'namespace': 'PSU', 'data_product': 'SEIRS_model/parameters', 'version': '1.0.0'}, 'data_product': 'SEIRS_model/parameters', 'registered': True}]'
# DEBUG:FAIRDataPipeline.ConfigYAML:Cleaning configuration
# DEBUG:FAIRDataPipeline.ConfigYAML:Checking for unparsed variables
# DEBUG:FAIRDataPipeline.ConfigYAML:Retrieving latest commit SHA with allow_dirty=False
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:latest_commit=c592f3bb913b69258f51b22b8d77b5fe44d4e12e'
# DEBUG:FAIRDataPipeline.ConfigYAML:Running configuration validation
# DEBUG:FAIRDataPipeline.Session:Setting up command execution
# DEBUG:FAIRDataPipeline.ConfigYAML:Setting up job script for execution
# DEBUG:FAIRDataPipeline.ConfigYAML:Will use shell: sh
# DEBUG:FAIRDataPipeline.ConfigYAML:Script command: python simpleModel/ext/SEIRSModelRun.py
# DEBUG:FAIRDataPipeline.ConfigYAML:Script written to: /home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/script.sh
# DEBUG:FAIRDataPipeline.ConfigYAML:Setting command script to '/home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/script.sh'
# DEBUG:FAIRDataPipeline.ConfigYAML:Set value run_metadata:script_path=/home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/script.sh'
# DEBUG:FAIRDataPipeline.ConfigYAML:Removing 'run_metadata.script'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.script_path=/home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/script.sh'
# DEBUG:FAIRDataPipeline.ConfigYAML:Configuration written to '/home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/config.yaml'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'shell=sh'
# DEBUG:FAIRDataPipeline.ConfigYAML:Returning 'run_metadata.script_path=/home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/script.sh'
# DEBUG:FAIRDataPipeline.ConfigYAML:Executing command: sh -e /home/jovyan/pySimpleModel/.fair/data_store/jobs/2024-06-12_13_47_09_810011/script.sh
# DEBUG:FAIRDataPipeline.Session:Tracking job hash 9fb1ccc4050f61196db7268a743b671a98c18a7d
# DEBUG:FAIRDataPipeline.Session:Updating staging post-run
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/data_product/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/2/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/2/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
# DEBUG:FAIRDataPipeline.Requests:Sending request of type 'get': http://127.0.0.1:8000/api/namespace/1/
# DEBUG:FAIRDataPipeline.Requests:Query parameters: {}
